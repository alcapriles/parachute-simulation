# %%
from numpy import linspace
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from numpy import linalg 
from numpy import multiply 
from numpy import concatenate

# %%
# Demora de 5 a 7 minutos para a pessoa pousar. Fonte: mundo estranho.

# %%
def func1(v, t): #v = [x, y, vy]
    m = 70
    g = 9.8
    k = 0.5
    dvdt = (k/m)*(v[1]**2) - g
    dydt = v[1]
    return [dydt, dvdt]

# %%
T = linspace(0,20)
v0 = [4000, 0]
y = odeint(func1,v0,T)
plt.plot(T, y[:,0])
plt.title('Trajetória')
plt.xlabel('t')
plt.ylabel('y')
plt.grid()
plt.show()

plt.plot(T, y[:,1])
plt.title('Velocidade')
plt.xlabel('t')
plt.ylabel('v')
plt.grid()
plt.show()

# %%
def forca_de_resistencia_do_ar(Vetor_velocidade, k):
    V_x = Vetor_velocidade[0]
    V_y = Vetor_velocidade[1]
    V = [V_x, V_y] #vetor velocidade resultante

    v = linalg.norm(V) #magnitude de V
    v_versor = V/v 
    
    F = multiply(-k*(v**2), v_versor)
    return F

#massa da pessoa em kg (70 kg) mais a massa do paraquedas em kg (18 kg) 
m = 88
#peso da pessoa em N:
P = 88*9.8

def func(A,t): #A = [x, y, Vx, Vy]
    dxdt = A[2]
    dydt = A[3]
    F = forca_de_resistencia_do_ar([A[2], A[3]], 0.5)
    dVxdt = F[0] / m
    dVydt = (F[1] - P) / m
    return [dxdt, dydt, dVxdt, dVydt]

def func_paraquedas_abre(A,t): #A = [x, y, Vx, Vy]
    dxdt = A[2]
    dydt = A[3]
    F = forca_de_resistencia_do_ar([A[2], A[3]], 2.0)
    dVxdt = F[0] / m
    dVydt = (F[1] - P) / m
    return [dxdt, dydt, dVxdt, dVydt]

#Condicões iniciais
#A = [x, y, Vx, Vy]
#x0 = 0
#y0 = 4000 #metros -- altitude
#Vx0 = 540 #metros por segundo
#Vy0 = 0

A0 = [0,4000,300,0]
T = linspace(0,20, 201)
T2 = linspace(20,40, 201)
M = odeint(func, A0, T, mxstep=500000000) 
l1 = M[-1,0]
l2 = M[-1,1]
l3 = M[-1,2]
l4 = M[-1,3]
A1 = [l1, l2, l3, l4]
M2 = odeint(func_paraquedas_abre, A1, T2, mxstep=500000000)
M3 = M + M2

plt.plot(M[:,0], M[:,1])
#slicing do numpy: dois pontos significa todas as linhas ou colunas
#exemplo: M[:,0] -- todas as linhas da coluna zero
#mais exemplo: M [:,1] -- todas as linhas da coluna 1
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trajetória antes de abrir o para-quedas')
plt.show() 


plt.plot(M3[:,0], M3[:,1])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Trajetória depois de abrir o para-quedas')
plt.show() 

plt.plot(T, M[:,3])
plt.xlabel('v')
plt.ylabel('t')
plt.title('Velocidade em y antes de abrir o para-quedas')
plt.show() 

T_final = concatenate((T, T2), axis=0)
M3 = concatenate((M, M2), axis = 0)

plt.plot(T_final, M3[:,3])
plt.xlabel('t')
plt.ylabel('v')
plt.title('Velocidade em y depois de abrir o para-quedas')
plt.show()
